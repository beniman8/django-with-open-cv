# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('happy-dog-outdoors-royalty-free-image-1652927740.jpg')

# %%
img
# Out:
# array([[[ 23,  52,  49],
#         [ 24,  53,  50],
#         [ 24,  53,  50],
#         ...,
#         [ 28, 102,  84],
#         [ 28, 102,  84],
#         [ 28, 102,  84]],
#
#        [[ 24,  53,  50],
#         [ 24,  53,  50],
#         [ 25,  54,  51],
#         ...,
#         [ 29, 103,  85],
#         [ 29, 103,  85],
#         [ 29, 103,  85]],
#
#        [[ 24,  53,  50],
#         [ 24,  53,  50],
#         [ 25,  54,  51],
#         ...,
#         [ 31, 105,  87],
#         [ 31, 105,  87],
#         [ 31, 105,  87]],
#
#        ...,
#
#        [[ 49,  56,  51],
#         [ 50,  57,  52],
#         [ 51,  58,  53],
#         ...,
#         [ 28, 111,  86],
#         [ 29, 112,  87],
#         [ 29, 112,  87]],
#
#        [[ 49,  56,  51],
#         [ 50,  57,  52],
#         [ 51,  58,  53],
#         ...,
#         [ 28, 111,  86],
#         [ 28, 111,  86],
#         [ 29, 112,  87]],
#
#        [[ 49,  56,  51],
#         [ 50,  57,  52],
#         [ 52,  59,  54],
#         ...,
#         [ 28, 111,  86],
#         [ 28, 111,  86],
#         [ 28, 111,  86]]], dtype=uint8)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1414, 948, 3)

# %%
plt.imshow(img)

# %%
normal = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(normal)

# %%
def get_image(image,cmap=None):
    plt.axis('off')
    plt.imshow(image,cmap=cmap)
    plt.show()

# %%
get_image(normal)

# %%
#Colorized
hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
get_image(hsv)

# %%
#Grayscale
gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
get_image(gray,cmap='gray')

# %%
# Blurred
width,height = normal.shape[:2]
print(width,height)

if width > 500:
    k=(50,50)
elif width > 200 and width <= 500:
    k=(25,25)
    
else:
    k=(10,10)
    
blur = cv2.blur(normal,k)
get_image(blur)
# Out:
# 1414 948

# %%
#Binary

v, binary = cv2.threshold(gray,100,255,cv2.THRESH_BINARY)
get_image(binary,cmap='gray')

# %%
#Inber

invert = cv2.bitwise_not(binary)
get_image(invert,cmap='gray')
